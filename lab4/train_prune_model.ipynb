# %% [markdown]
# ##掛載雲端硬碟

# %%
# from google.colab import drive
# drive.mount('/content/drive')

# %% [markdown]
# ##更改檔案所在路徑

# %%
# Change to your own folder !!!
# %cd /content/drive/MyDrive/Colab\ Notebooks/EAI_Lab4_2023

# %% [markdown]
# ## Import library

# %%
from __future__ import print_function
import os
import argparse

import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torchvision import datasets, transforms
from torch.autograd import Variable

from models import vgg

# %% [markdown]
# ## 設定超參數

# %%
TRAIN_BATCH_SIZE = 100
TEST_BATCH_SIZE = 1000
EPOCHS = 20
LEARNING_RATE = 0.1
MOMENTUM = 0.9
WEIGHT_DECAY = 1e-4
LOG_INTERVAL = 100
CUDA = True
SEED = 1

RESUME = True
START_EPOCH = 0

PRUNE_PATH = './model_prune.pth'
PRUNE_FINETUNE_PATH = './model_prune_finetune.pth'

# %% [markdown]
# ####檢查是否檢查是否可使用GPU

# %%
if(torch.cuda.is_available()):
    CUDA = True
    kwargs = {'num_workers': 1, 'pin_memory': True}
    torch.cuda.manual_seed(SEED)
else:
    CUDA = False
    kwargs = {}

# %% [markdown]
# ##下載資料集

# %% [markdown]
# 這裡將訓練集做Augmentation(Pad, RandCrop, Random)，測試集不用做Augmentation

# %%
#### DATASET ####
train_loader = torch.utils.data.DataLoader(
    datasets.CIFAR10('./data', train=True, download=True,
                   transform=transforms.Compose([
                       transforms.Pad(4),
                       transforms.RandomCrop(32),
                       transforms.RandomHorizontalFlip(),
                       transforms.ToTensor(),
                       transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))
                   ])),
    batch_size=TRAIN_BATCH_SIZE, shuffle=True, **kwargs)
test_loader = torch.utils.data.DataLoader(
    datasets.CIFAR10('./data', train=False, transform=transforms.Compose([
                       transforms.ToTensor(),
                       transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))
                   ])),
    batch_size=TEST_BATCH_SIZE, shuffle=True, **kwargs)
# Out:
# Files already downloaded and verified

# %% [markdown]
# ## 載入剪枝後的網路與權重

# %%
model = None
if(RESUME):
  checkpoint = torch.load(PRUNE_PATH)
  model = vgg(cfg=checkpoint['cfg'])
  model.load_state_dict(checkpoint['state_dict'])

  print('RESUME PRUNE MODEL')

if CUDA:
    model.cuda()
# Out:
# RESUME PRUNE MODEL

# %% [markdown]
# ##設定Optimizer，這裡使用Stocastic Gradient Descent with

# %%
optimizer = optim.SGD(model.parameters(), lr=LEARNING_RATE, momentum=MOMENTUM, weight_decay=WEIGHT_DECAY)

# %% [markdown]
# ## 定義訓練跟測試函數

# %%
#### 訓練函數 #####

train_acc = []
test_acc = []

# 注意: 需自行撰寫儲存每個epoch之train acc的code，以便後續繪製train acc結果圖!
def train(epoch):
    model.train()
    accuracy_per_batch = []
    for batch_idx, (data, target) in enumerate(train_loader):
        if CUDA:
            data, target = data.cuda(), target.cuda()
        data, target = Variable(data), Variable(target)
        optimizer.zero_grad()
        output = model(data)
        loss = F.cross_entropy(output, target)
        loss.backward()
        optimizer.step()
        if batch_idx % LOG_INTERVAL == 0:
            print('\nTrain Epoch: {} [{}/{} ({:.1f}%)]\tLoss: {:.6f}'.format(
                epoch, batch_idx * len(data), len(train_loader.dataset),
                100. * batch_idx / len(train_loader), loss.data.item()))

        # Store training accuracy of current batch
        pred = output.data.max(1, keepdim=True)[1]
        correct = pred.eq(target.data.view_as(pred)).cpu().sum()
        accuracy = correct / float(len(data))
        accuracy_per_batch.append(accuracy)

    # Store training accuracy of current epoch
    train_acc.append(sum(accuracy_per_batch) / len(accuracy_per_batch))


#### 測試函數 ####
def test():
    model.eval()
    test_loss = 0
    correct = 0

    with torch.no_grad():
      for data, target in test_loader:
          if CUDA:
              data, target = data.cuda(), target.cuda()
          data, target = Variable(data), Variable(target)
          output = model(data)
          test_loss += F.cross_entropy(output, target, reduction='sum').data.item()
          pred = output.data.max(1, keepdim=True)[1]
          correct += pred.eq(target.data.view_as(pred)).cpu().sum()

      test_loss /= len(test_loader.dataset)
      print('\nTest set: Average loss: {:.4f}, Accuracy: {}/{} ({:.1f}%)\n'.format(
          test_loss, correct, len(test_loader.dataset),
          100. * correct / len(test_loader.dataset)))
      
      # Store testing accuracy of current epoch
      test_acc.append(correct / float(len(test_loader.dataset)))
      
      return correct / float(len(test_loader.dataset))

best_prec1 = 0.
for epoch in range(START_EPOCH, EPOCHS):
    # Learning Rate在0.5EPOCHS與0.75EPOCHS調整為原本之十分之一
    if epoch in [EPOCHS*0.5, EPOCHS*0.75]:
        for param_group in optimizer.param_groups:
            param_group['lr'] *= 0.1
    train(epoch)
    prec1 = test()

    # 儲存模型權重，方便做後續剪枝,後續訓練
    if(prec1 > best_prec1):
        torch.save({
            'epoch': epoch + 1,
            'state_dict': model.state_dict(),
            'best_prec1': best_prec1,
            'optimizer': optimizer.state_dict(),
        }, PRUNE_FINETUNE_PATH)

    best_prec1 = max(prec1, best_prec1)

print('\n TRAIN PRUNED MODEL DONE!')
# Out:
# Train Epoch: 0 [0/50000 (0.0%)]	Loss: 0.689965
#
# Train Epoch: 0 [10000/50000 (20.0%)]	Loss: 0.670127
#
# Train Epoch: 0 [20000/50000 (40.0%)]	Loss: 0.601255
#
# Train Epoch: 0 [30000/50000 (60.0%)]	Loss: 0.440768
#
# Train Epoch: 0 [40000/50000 (80.0%)]	Loss: 0.239888
#
# Test set: Average loss: 0.4959, Accuracy: 8538/10000 (85.4%)
#
#
# Train Epoch: 1 [0/50000 (0.0%)]	Loss: 0.410486
#
# Train Epoch: 1 [10000/50000 (20.0%)]	Loss: 0.221855
#
# Train Epoch: 1 [20000/50000 (40.0%)]	Loss: 0.358205
#
# Train Epoch: 1 [30000/50000 (60.0%)]	Loss: 0.266484
#
# Train Epoch: 1 [40000/50000 (80.0%)]	Loss: 0.378187
#
# Test set: Average loss: 0.4373, Accuracy: 8594/10000 (85.9%)
#
#
# Train Epoch: 2 [0/50000 (0.0%)]	Loss: 0.355073
#
# Train Epoch: 2 [10000/50000 (20.0%)]	Loss: 0.372916
#
# Train Epoch: 2 [20000/50000 (40.0%)]	Loss: 0.301011
#
# Train Epoch: 2 [30000/50000 (60.0%)]	Loss: 0.278351
#
# Train Epoch: 2 [40000/50000 (80.0%)]	Loss: 0.358025
#
# Test set: Average loss: 0.5049, Accuracy: 8502/10000 (85.0%)
#
#
# Train Epoch: 3 [0/50000 (0.0%)]	Loss: 0.203881
#
# Train Epoch: 3 [10000/50000 (20.0%)]	Loss: 0.253751
#
# Train Epoch: 3 [20000/50000 (40.0%)]	Loss: 0.319633
#
# Train Epoch: 3 [30000/50000 (60.0%)]	Loss: 0.333211
#
# Train Epoch: 3 [40000/50000 (80.0%)]	Loss: 0.284489
#
# Test set: Average loss: 0.4641, Accuracy: 8635/10000 (86.3%)
#
#
# Train Epoch: 4 [0/50000 (0.0%)]	Loss: 0.288484
#
# Train Epoch: 4 [10000/50000 (20.0%)]	Loss: 0.467369
#
# Train Epoch: 4 [20000/50000 (40.0%)]	Loss: 0.131837
#
# Train Epoch: 4 [30000/50000 (60.0%)]	Loss: 0.485816
#
# Train Epoch: 4 [40000/50000 (80.0%)]	Loss: 0.330097
#
# Test set: Average loss: 0.5185, Accuracy: 8437/10000 (84.4%)
#
#
# Train Epoch: 5 [0/50000 (0.0%)]	Loss: 0.253990
#
# Train Epoch: 5 [10000/50000 (20.0%)]	Loss: 0.220889
#
# Train Epoch: 5 [20000/50000 (40.0%)]	Loss: 0.434459
#
# Train Epoch: 5 [30000/50000 (60.0%)]	Loss: 0.240420
#
# Train Epoch: 5 [40000/50000 (80.0%)]	Loss: 0.312680
#
# Test set: Average loss: 0.3827, Accuracy: 8816/10000 (88.2%)
#
#
# Train Epoch: 6 [0/50000 (0.0%)]	Loss: 0.291591
#
# Train Epoch: 6 [10000/50000 (20.0%)]	Loss: 0.240133
#
# Train Epoch: 6 [20000/50000 (40.0%)]	Loss: 0.269980
#
# Train Epoch: 6 [30000/50000 (60.0%)]	Loss: 0.437678
#
# Train Epoch: 6 [40000/50000 (80.0%)]	Loss: 0.310937
#
# Test set: Average loss: 0.4843, Accuracy: 8562/10000 (85.6%)
#
#
# Train Epoch: 7 [0/50000 (0.0%)]	Loss: 0.209312
#
# Train Epoch: 7 [10000/50000 (20.0%)]	Loss: 0.137890
#
# Train Epoch: 7 [20000/50000 (40.0%)]	Loss: 0.290159
#
# Train Epoch: 7 [30000/50000 (60.0%)]	Loss: 0.246867
#
# Train Epoch: 7 [40000/50000 (80.0%)]	Loss: 0.282393
#
# Test set: Average loss: 0.4566, Accuracy: 8623/10000 (86.2%)
#
#
# Train Epoch: 8 [0/50000 (0.0%)]	Loss: 0.305987
#
# Train Epoch: 8 [10000/50000 (20.0%)]	Loss: 0.238587
#
# Train Epoch: 8 [20000/50000 (40.0%)]	Loss: 0.214958
#
# Train Epoch: 8 [30000/50000 (60.0%)]	Loss: 0.240371
#
# Train Epoch: 8 [40000/50000 (80.0%)]	Loss: 0.273789
#
# Test set: Average loss: 0.3802, Accuracy: 8820/10000 (88.2%)
#
#
# Train Epoch: 9 [0/50000 (0.0%)]	Loss: 0.225772
#
# Train Epoch: 9 [10000/50000 (20.0%)]	Loss: 0.241641
#
# Train Epoch: 9 [20000/50000 (40.0%)]	Loss: 0.253024
#
# Train Epoch: 9 [30000/50000 (60.0%)]	Loss: 0.245316
#
# Train Epoch: 9 [40000/50000 (80.0%)]	Loss: 0.223656
#
# Test set: Average loss: 0.4127, Accuracy: 8781/10000 (87.8%)
#
#
# Train Epoch: 10 [0/50000 (0.0%)]	Loss: 0.226994
#
# Train Epoch: 10 [10000/50000 (20.0%)]	Loss: 0.147850
#
# Train Epoch: 10 [20000/50000 (40.0%)]	Loss: 0.072804
#
# Train Epoch: 10 [30000/50000 (60.0%)]	Loss: 0.068538
#
# Train Epoch: 10 [40000/50000 (80.0%)]	Loss: 0.034146
#
# Test set: Average loss: 0.2632, Accuracy: 9187/10000 (91.9%)
#
#
# Train Epoch: 11 [0/50000 (0.0%)]	Loss: 0.101273
#
# Train Epoch: 11 [10000/50000 (20.0%)]	Loss: 0.052267
#
# Train Epoch: 11 [20000/50000 (40.0%)]	Loss: 0.170178
#
# Train Epoch: 11 [30000/50000 (60.0%)]	Loss: 0.161400
#
# Train Epoch: 11 [40000/50000 (80.0%)]	Loss: 0.125393
#
# Test set: Average loss: 0.2640, Accuracy: 9224/10000 (92.2%)
#
#
# Train Epoch: 12 [0/50000 (0.0%)]	Loss: 0.082902
#
# Train Epoch: 12 [10000/50000 (20.0%)]	Loss: 0.028623
#
# Train Epoch: 12 [20000/50000 (40.0%)]	Loss: 0.083461
#
# Train Epoch: 12 [30000/50000 (60.0%)]	Loss: 0.077358
#
# Train Epoch: 12 [40000/50000 (80.0%)]	Loss: 0.088356
#
# Test set: Average loss: 0.2628, Accuracy: 9238/10000 (92.4%)
#
#
# Train Epoch: 13 [0/50000 (0.0%)]	Loss: 0.170715
#
# Train Epoch: 13 [10000/50000 (20.0%)]	Loss: 0.090937
#
# Train Epoch: 13 [20000/50000 (40.0%)]	Loss: 0.071884
#
# Train Epoch: 13 [30000/50000 (60.0%)]	Loss: 0.136903
#
# Train Epoch: 13 [40000/50000 (80.0%)]	Loss: 0.052990
#
# Test set: Average loss: 0.2597, Accuracy: 9261/10000 (92.6%)
#
#
# Train Epoch: 14 [0/50000 (0.0%)]	Loss: 0.030995
#
# Train Epoch: 14 [10000/50000 (20.0%)]	Loss: 0.037959
#
# Train Epoch: 14 [20000/50000 (40.0%)]	Loss: 0.091057
#
# Train Epoch: 14 [30000/50000 (60.0%)]	Loss: 0.084497
#
# Train Epoch: 14 [40000/50000 (80.0%)]	Loss: 0.079501
#
# Test set: Average loss: 0.2669, Accuracy: 9270/10000 (92.7%)
#
#
# Train Epoch: 15 [0/50000 (0.0%)]	Loss: 0.064846
#
# Train Epoch: 15 [10000/50000 (20.0%)]	Loss: 0.143522
#
# Train Epoch: 15 [20000/50000 (40.0%)]	Loss: 0.023512
#
# Train Epoch: 15 [30000/50000 (60.0%)]	Loss: 0.101069
#
# Train Epoch: 15 [40000/50000 (80.0%)]	Loss: 0.064252
#
# Test set: Average loss: 0.2624, Accuracy: 9272/10000 (92.7%)
#
#
# Train Epoch: 16 [0/50000 (0.0%)]	Loss: 0.063296
#
# Train Epoch: 16 [10000/50000 (20.0%)]	Loss: 0.080773
#
# Train Epoch: 16 [20000/50000 (40.0%)]	Loss: 0.093059
#
# Train Epoch: 16 [30000/50000 (60.0%)]	Loss: 0.070476
#
# Train Epoch: 16 [40000/50000 (80.0%)]	Loss: 0.024994
#
# Test set: Average loss: 0.2615, Accuracy: 9280/10000 (92.8%)
#
#
# Train Epoch: 17 [0/50000 (0.0%)]	Loss: 0.093457
#
# Train Epoch: 17 [10000/50000 (20.0%)]	Loss: 0.058134
#
# Train Epoch: 17 [20000/50000 (40.0%)]	Loss: 0.071674
#
# Train Epoch: 17 [30000/50000 (60.0%)]	Loss: 0.059244
#
# Train Epoch: 17 [40000/50000 (80.0%)]	Loss: 0.048663
#
# Test set: Average loss: 0.2603, Accuracy: 9281/10000 (92.8%)
#
#
# Train Epoch: 18 [0/50000 (0.0%)]	Loss: 0.037472
#
# Train Epoch: 18 [10000/50000 (20.0%)]	Loss: 0.041072
#
# Train Epoch: 18 [20000/50000 (40.0%)]	Loss: 0.039331
#
# Train Epoch: 18 [30000/50000 (60.0%)]	Loss: 0.033604
#
# Train Epoch: 18 [40000/50000 (80.0%)]	Loss: 0.050121
#
# Test set: Average loss: 0.2598, Accuracy: 9283/10000 (92.8%)
#
#
# Train Epoch: 19 [0/50000 (0.0%)]	Loss: 0.037913
#
# Train Epoch: 19 [10000/50000 (20.0%)]	Loss: 0.009055
#
# Train Epoch: 19 [20000/50000 (40.0%)]	Loss: 0.073778
#
# Train Epoch: 19 [30000/50000 (60.0%)]	Loss: 0.108716
#
# Train Epoch: 19 [40000/50000 (80.0%)]	Loss: 0.032460
#
# Test set: Average loss: 0.2634, Accuracy: 9284/10000 (92.8%)
#
#
#  TRAIN PRUNED MODEL DONE!

# %% [markdown]
# ## 繪製Fine-tuning結果圖

# %%
#繪製Fine-tuning結果圖
import matplotlib.pyplot as plt
import numpy as np

plt.figure(figsize=(12, 8))
plt.plot(np.arange(1, EPOCHS+1), train_acc, label='Train')
plt.plot(np.arange(1, EPOCHS+1), test_acc, label='Test')
plt.title('Fine-tuning Result - Prune Ratio: 0.5')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()
plt.savefig('prune_finetune_result_05.png')
plt.show()
