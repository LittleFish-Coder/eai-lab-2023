# %% [markdown]
# ##掛載雲端硬碟

# %%
# from google.colab import drive
# drive.mount('/content/drive')

# %% [markdown]
# ##更改檔案所在路徑

# %%
# Change to your own folder !!!
# %cd /content/drive/MyDrive/Colab\ Notebooks/EAI_Lab4_2023

# %% [markdown]
# ## Import library

# %%
from __future__ import print_function
import os
import argparse

import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torchvision import datasets, transforms
from torch.autograd import Variable

from models import vgg

# %% [markdown]
# ## 設定超參數

# %%
TRAIN_BATCH_SIZE = 100
TEST_BATCH_SIZE = 1000
EPOCHS = 20
LEARNING_RATE = 0.1
MOMENTUM = 0.9
WEIGHT_DECAY = 1e-4
LOG_INTERVAL = 100
CUDA = True
SEED = 1

RESUME = True
START_EPOCH = 0

PRUNE_PATH = './model_prune.pth'
PRUNE_FINETUNE_PATH = './model_prune_finetune.pth'

# %% [markdown]
# ####檢查是否檢查是否可使用GPU

# %%
if(torch.cuda.is_available()):
    CUDA = True
    kwargs = {'num_workers': 1, 'pin_memory': True}
    torch.cuda.manual_seed(SEED)
else:
    CUDA = False
    kwargs = {}

# %% [markdown]
# ##下載資料集

# %% [markdown]
# 這裡將訓練集做Augmentation(Pad, RandCrop, Random)，測試集不用做Augmentation

# %%
#### DATASET ####
train_loader = torch.utils.data.DataLoader(
    datasets.CIFAR10('./data', train=True, download=True,
                   transform=transforms.Compose([
                       transforms.Pad(4),
                       transforms.RandomCrop(32),
                       transforms.RandomHorizontalFlip(),
                       transforms.ToTensor(),
                       transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))
                   ])),
    batch_size=TRAIN_BATCH_SIZE, shuffle=True, **kwargs)
test_loader = torch.utils.data.DataLoader(
    datasets.CIFAR10('./data', train=False, transform=transforms.Compose([
                       transforms.ToTensor(),
                       transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))
                   ])),
    batch_size=TEST_BATCH_SIZE, shuffle=True, **kwargs)
# Out:
# Files already downloaded and verified

# %% [markdown]
# ## 載入剪枝後的網路與權重

# %%
model = None
if(RESUME):
  checkpoint = torch.load(PRUNE_PATH)
  model = vgg(cfg=checkpoint['cfg'])
  model.load_state_dict(checkpoint['state_dict'])

  print('RESUME PRUNE MODEL')

if CUDA:
    model.cuda()
# Out:
# RESUME PRUNE MODEL

# %% [markdown]
# ##設定Optimizer，這裡使用Stocastic Gradient Descent with

# %%
optimizer = optim.SGD(model.parameters(), lr=LEARNING_RATE, momentum=MOMENTUM, weight_decay=WEIGHT_DECAY)

# %% [markdown]
# ## 定義訓練跟測試函數

# %%
#### 訓練函數 #####

train_acc = []
test_acc = []

# 注意: 需自行撰寫儲存每個epoch之train acc的code，以便後續繪製train acc結果圖!
def train(epoch):
    model.train()
    accuracy_per_batch = []
    for batch_idx, (data, target) in enumerate(train_loader):
        if CUDA:
            data, target = data.cuda(), target.cuda()
        data, target = Variable(data), Variable(target)
        optimizer.zero_grad()
        output = model(data)
        loss = F.cross_entropy(output, target)
        loss.backward()
        optimizer.step()
        if batch_idx % LOG_INTERVAL == 0:
            print('\nTrain Epoch: {} [{}/{} ({:.1f}%)]\tLoss: {:.6f}'.format(
                epoch, batch_idx * len(data), len(train_loader.dataset),
                100. * batch_idx / len(train_loader), loss.data.item()))

        # Store training accuracy of current batch
        pred = output.data.max(1, keepdim=True)[1]
        correct = pred.eq(target.data.view_as(pred)).cpu().sum()
        accuracy = correct / float(len(data))
        accuracy_per_batch.append(accuracy)

    # Store training accuracy of current epoch
    train_acc.append(sum(accuracy_per_batch) / len(accuracy_per_batch))


#### 測試函數 ####
def test():
    model.eval()
    test_loss = 0
    correct = 0

    with torch.no_grad():
      for data, target in test_loader:
          if CUDA:
              data, target = data.cuda(), target.cuda()
          data, target = Variable(data), Variable(target)
          output = model(data)
          test_loss += F.cross_entropy(output, target, reduction='sum').data.item()
          pred = output.data.max(1, keepdim=True)[1]
          correct += pred.eq(target.data.view_as(pred)).cpu().sum()

      test_loss /= len(test_loader.dataset)
      print('\nTest set: Average loss: {:.4f}, Accuracy: {}/{} ({:.1f}%)\n'.format(
          test_loss, correct, len(test_loader.dataset),
          100. * correct / len(test_loader.dataset)))
      
      # Store testing accuracy of current epoch
      test_acc.append(correct / float(len(test_loader.dataset)))
      
      return correct / float(len(test_loader.dataset))

best_prec1 = 0.
for epoch in range(START_EPOCH, EPOCHS):
    # Learning Rate在0.5EPOCHS與0.75EPOCHS調整為原本之十分之一
    if epoch in [EPOCHS*0.5, EPOCHS*0.75]:
        for param_group in optimizer.param_groups:
            param_group['lr'] *= 0.1
    train(epoch)
    prec1 = test()

    # 儲存模型權重，方便做後續剪枝,後續訓練
    if(prec1 > best_prec1):
        torch.save({
            'epoch': epoch + 1,
            'state_dict': model.state_dict(),
            'best_prec1': best_prec1,
            'optimizer': optimizer.state_dict(),
        }, PRUNE_FINETUNE_PATH)

    best_prec1 = max(prec1, best_prec1)

print('\n TRAIN PRUNED MODEL DONE!')
# Out:
# Train Epoch: 0 [0/50000 (0.0%)]	Loss: 2.442855
#
# Train Epoch: 0 [10000/50000 (20.0%)]	Loss: 1.617908
#
# Train Epoch: 0 [20000/50000 (40.0%)]	Loss: 1.643098
#
# Train Epoch: 0 [30000/50000 (60.0%)]	Loss: 1.467178
#
# Train Epoch: 0 [40000/50000 (80.0%)]	Loss: 1.456788
#
# Test set: Average loss: 1.9965, Accuracy: 2864/10000 (28.6%)
#
#
# Train Epoch: 1 [0/50000 (0.0%)]	Loss: 1.244047
#
# Train Epoch: 1 [10000/50000 (20.0%)]	Loss: 0.934853
#
# Train Epoch: 1 [20000/50000 (40.0%)]	Loss: 0.878457
#
# Train Epoch: 1 [30000/50000 (60.0%)]	Loss: 1.151588
#
# Train Epoch: 1 [40000/50000 (80.0%)]	Loss: 0.956944
#
# Test set: Average loss: 1.9868, Accuracy: 4032/10000 (40.3%)
#
#
# Train Epoch: 2 [0/50000 (0.0%)]	Loss: 0.826797
#
# Train Epoch: 2 [10000/50000 (20.0%)]	Loss: 0.837246
#
# Train Epoch: 2 [20000/50000 (40.0%)]	Loss: 1.012870
#
# Train Epoch: 2 [30000/50000 (60.0%)]	Loss: 0.723037
#
# Train Epoch: 2 [40000/50000 (80.0%)]	Loss: 0.791564
#
# Test set: Average loss: 0.9695, Accuracy: 6825/10000 (68.2%)
#
#
# Train Epoch: 3 [0/50000 (0.0%)]	Loss: 0.746612
#
# Train Epoch: 3 [10000/50000 (20.0%)]	Loss: 0.887433
#
# Train Epoch: 3 [20000/50000 (40.0%)]	Loss: 0.859314
#
# Train Epoch: 3 [30000/50000 (60.0%)]	Loss: 0.704014
#
# Train Epoch: 3 [40000/50000 (80.0%)]	Loss: 0.794618
#
# Test set: Average loss: 0.7999, Accuracy: 7399/10000 (74.0%)
#
#
# Train Epoch: 4 [0/50000 (0.0%)]	Loss: 0.699446
#
# Train Epoch: 4 [10000/50000 (20.0%)]	Loss: 0.555858
#
# Train Epoch: 4 [20000/50000 (40.0%)]	Loss: 0.803218
#
# Train Epoch: 4 [30000/50000 (60.0%)]	Loss: 0.660926
#
# Train Epoch: 4 [40000/50000 (80.0%)]	Loss: 0.830599
#
# Test set: Average loss: 0.7434, Accuracy: 7628/10000 (76.3%)
#
#
# Train Epoch: 5 [0/50000 (0.0%)]	Loss: 0.573457
#
# Train Epoch: 5 [10000/50000 (20.0%)]	Loss: 0.518589
#
# Train Epoch: 5 [20000/50000 (40.0%)]	Loss: 0.637230
#
# Train Epoch: 5 [30000/50000 (60.0%)]	Loss: 0.549651
#
# Train Epoch: 5 [40000/50000 (80.0%)]	Loss: 0.824696
#
# Test set: Average loss: 1.1684, Accuracy: 6701/10000 (67.0%)
#
#
# Train Epoch: 6 [0/50000 (0.0%)]	Loss: 0.494057
#
# Train Epoch: 6 [10000/50000 (20.0%)]	Loss: 0.561202
#
# Train Epoch: 6 [20000/50000 (40.0%)]	Loss: 0.550182
#
# Train Epoch: 6 [30000/50000 (60.0%)]	Loss: 0.577900
#
# Train Epoch: 6 [40000/50000 (80.0%)]	Loss: 0.728228
#
# Test set: Average loss: 1.4732, Accuracy: 6328/10000 (63.3%)
#
#
# Train Epoch: 7 [0/50000 (0.0%)]	Loss: 0.661755
#
# Train Epoch: 7 [10000/50000 (20.0%)]	Loss: 0.491693
#
# Train Epoch: 7 [20000/50000 (40.0%)]	Loss: 0.509657
#
# Train Epoch: 7 [30000/50000 (60.0%)]	Loss: 0.602752
#
# Train Epoch: 7 [40000/50000 (80.0%)]	Loss: 0.616916
#
# Test set: Average loss: 0.8240, Accuracy: 7504/10000 (75.0%)
#
#
# Train Epoch: 8 [0/50000 (0.0%)]	Loss: 0.667388
#
# Train Epoch: 8 [10000/50000 (20.0%)]	Loss: 0.666796
#
# Train Epoch: 8 [20000/50000 (40.0%)]	Loss: 0.850876
#
# Train Epoch: 8 [30000/50000 (60.0%)]	Loss: 0.606366
#
# Train Epoch: 8 [40000/50000 (80.0%)]	Loss: 0.749550
#
# Test set: Average loss: 0.8068, Accuracy: 7437/10000 (74.4%)
#
#
# Train Epoch: 9 [0/50000 (0.0%)]	Loss: 0.523867
#
# Train Epoch: 9 [10000/50000 (20.0%)]	Loss: 0.508060
#
# Train Epoch: 9 [20000/50000 (40.0%)]	Loss: 0.678495
#
# Train Epoch: 9 [30000/50000 (60.0%)]	Loss: 0.328407
#
# Train Epoch: 9 [40000/50000 (80.0%)]	Loss: 0.568784
#
# Test set: Average loss: 0.8439, Accuracy: 7565/10000 (75.7%)
#
#
# Train Epoch: 10 [0/50000 (0.0%)]	Loss: 0.685069
#
# Train Epoch: 10 [10000/50000 (20.0%)]	Loss: 0.508723
#
# Train Epoch: 10 [20000/50000 (40.0%)]	Loss: 0.535433
#
# Train Epoch: 10 [30000/50000 (60.0%)]	Loss: 0.315134
#
# Train Epoch: 10 [40000/50000 (80.0%)]	Loss: 0.421273
#
# Test set: Average loss: 0.4464, Accuracy: 8643/10000 (86.4%)
#
#
# Train Epoch: 11 [0/50000 (0.0%)]	Loss: 0.431358
#
# Train Epoch: 11 [10000/50000 (20.0%)]	Loss: 0.401191
#
# Train Epoch: 11 [20000/50000 (40.0%)]	Loss: 0.371647
#
# Train Epoch: 11 [30000/50000 (60.0%)]	Loss: 0.243833
#
# Train Epoch: 11 [40000/50000 (80.0%)]	Loss: 0.567852
#
# Test set: Average loss: 0.4395, Accuracy: 8665/10000 (86.7%)
#
#
# Train Epoch: 12 [0/50000 (0.0%)]	Loss: 0.300531
#
# Train Epoch: 12 [10000/50000 (20.0%)]	Loss: 0.367002
#
# Train Epoch: 12 [20000/50000 (40.0%)]	Loss: 0.319880
#
# Train Epoch: 12 [30000/50000 (60.0%)]	Loss: 0.271545
#
# Train Epoch: 12 [40000/50000 (80.0%)]	Loss: 0.304642
#
# Test set: Average loss: 0.4300, Accuracy: 8687/10000 (86.9%)
#
#
# Train Epoch: 13 [0/50000 (0.0%)]	Loss: 0.363181
#
# Train Epoch: 13 [10000/50000 (20.0%)]	Loss: 0.269459
#
# Train Epoch: 13 [20000/50000 (40.0%)]	Loss: 0.779309
#
# Train Epoch: 13 [30000/50000 (60.0%)]	Loss: 0.304996
#
# Train Epoch: 13 [40000/50000 (80.0%)]	Loss: 0.224832
#
# Test set: Average loss: 0.4372, Accuracy: 8695/10000 (86.9%)
#
#
# Train Epoch: 14 [0/50000 (0.0%)]	Loss: 0.214271
#
# Train Epoch: 14 [10000/50000 (20.0%)]	Loss: 0.392152
#
# Train Epoch: 14 [20000/50000 (40.0%)]	Loss: 0.233409
#
# Train Epoch: 14 [30000/50000 (60.0%)]	Loss: 0.270995
#
# Train Epoch: 14 [40000/50000 (80.0%)]	Loss: 0.309042
#
# Test set: Average loss: 0.4421, Accuracy: 8726/10000 (87.3%)
#
#
# Train Epoch: 15 [0/50000 (0.0%)]	Loss: 0.523616
#
# Train Epoch: 15 [10000/50000 (20.0%)]	Loss: 0.310508
#
# Train Epoch: 15 [20000/50000 (40.0%)]	Loss: 0.548233
#
# Train Epoch: 15 [30000/50000 (60.0%)]	Loss: 0.177885
#
# Train Epoch: 15 [40000/50000 (80.0%)]	Loss: 0.239207
#
# Test set: Average loss: 0.4169, Accuracy: 8753/10000 (87.5%)
#
#
# Train Epoch: 16 [0/50000 (0.0%)]	Loss: 0.288190
#
# Train Epoch: 16 [10000/50000 (20.0%)]	Loss: 0.669308
#
# Train Epoch: 16 [20000/50000 (40.0%)]	Loss: 0.404320
#
# Train Epoch: 16 [30000/50000 (60.0%)]	Loss: 0.402521
#
# Train Epoch: 16 [40000/50000 (80.0%)]	Loss: 0.274285
#
# Test set: Average loss: 0.4134, Accuracy: 8767/10000 (87.7%)
#
#
# Train Epoch: 17 [0/50000 (0.0%)]	Loss: 0.371980
#
# Train Epoch: 17 [10000/50000 (20.0%)]	Loss: 0.447020
#
# Train Epoch: 17 [20000/50000 (40.0%)]	Loss: 0.162879
#
# Train Epoch: 17 [30000/50000 (60.0%)]	Loss: 0.252766
#
# Train Epoch: 17 [40000/50000 (80.0%)]	Loss: 0.331049
#
# Test set: Average loss: 0.4118, Accuracy: 8776/10000 (87.8%)
#
#
# Train Epoch: 18 [0/50000 (0.0%)]	Loss: 0.245243
#
# Train Epoch: 18 [10000/50000 (20.0%)]	Loss: 0.297852
#
# Train Epoch: 18 [20000/50000 (40.0%)]	Loss: 0.171243
#
# Train Epoch: 18 [30000/50000 (60.0%)]	Loss: 0.428896
#
# Train Epoch: 18 [40000/50000 (80.0%)]	Loss: 0.333400
#
# Test set: Average loss: 0.4170, Accuracy: 8762/10000 (87.6%)
#
#
# Train Epoch: 19 [0/50000 (0.0%)]	Loss: 0.268410
#
# Train Epoch: 19 [10000/50000 (20.0%)]	Loss: 0.254841
#
# Train Epoch: 19 [20000/50000 (40.0%)]	Loss: 0.334974
#
# Train Epoch: 19 [30000/50000 (60.0%)]	Loss: 0.287209
#
# Train Epoch: 19 [40000/50000 (80.0%)]	Loss: 0.222518
#
# Test set: Average loss: 0.4151, Accuracy: 8771/10000 (87.7%)
#
#
#  TRAIN PRUNED MODEL DONE!

# %% [markdown]
# ## 繪製Fine-tuning結果圖

# %%
#繪製Fine-tuning結果圖
import matplotlib.pyplot as plt
import numpy as np

plt.figure(figsize=(12, 8))
plt.plot(np.arange(1, EPOCHS+1), train_acc, label='Train')
plt.plot(np.arange(1, EPOCHS+1), test_acc, label='Test')
plt.title('Fine-tuning Result - Prune Ratio: 0.9')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()
plt.savefig('prune_finetune_result_09.png')
plt.show()
