# %% [markdown]
# ##掛載雲端硬碟

# %%
# from google.colab import drive
# drive.mount('/content/drive')

# %% [markdown]
# ##更改檔案所在路徑

# %%
# Change to your own folder !!!
# %cd /content/drive/MyDrive/Colab\ Notebooks/EAI_Lab4_2023

# %% [markdown]
# ## Import library

# %%
from __future__ import print_function
import os
import argparse

import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torchvision import datasets, transforms
from torch.autograd import Variable

from models import vgg

# %% [markdown]
# ## 設定超參數

# %%
TRAIN_BATCH_SIZE = 100
TEST_BATCH_SIZE = 1000
EPOCHS = 20
LEARNING_RATE = 0.1
MOMENTUM = 0.9
WEIGHT_DECAY = 1e-4
LOG_INTERVAL = 100
CUDA = True
SEED = 1

RESUME = True
START_EPOCH = 0

PRUNE_PATH = './model_prune.pth'
PRUNE_FINETUNE_PATH = './model_prune_finetune.pth'

# %% [markdown]
# ####檢查是否檢查是否可使用GPU

# %%
if(torch.cuda.is_available()):
    CUDA = True
    kwargs = {'num_workers': 1, 'pin_memory': True}
    torch.cuda.manual_seed(SEED)
else:
    CUDA = False
    kwargs = {}

# %% [markdown]
# ##下載資料集

# %% [markdown]
# 這裡將訓練集做Augmentation(Pad, RandCrop, Random)，測試集不用做Augmentation

# %%
#### DATASET ####
train_loader = torch.utils.data.DataLoader(
    datasets.CIFAR10('./data', train=True, download=True,
                   transform=transforms.Compose([
                       transforms.Pad(4),
                       transforms.RandomCrop(32),
                       transforms.RandomHorizontalFlip(),
                       transforms.ToTensor(),
                       transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))
                   ])),
    batch_size=TRAIN_BATCH_SIZE, shuffle=True, **kwargs)
test_loader = torch.utils.data.DataLoader(
    datasets.CIFAR10('./data', train=False, transform=transforms.Compose([
                       transforms.ToTensor(),
                       transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))
                   ])),
    batch_size=TEST_BATCH_SIZE, shuffle=True, **kwargs)
# Out:
# Files already downloaded and verified

# %% [markdown]
# ## 載入剪枝後的網路與權重

# %%
model = None
if(RESUME):
  checkpoint = torch.load(PRUNE_PATH)
  model = vgg(cfg=checkpoint['cfg'])
  model.load_state_dict(checkpoint['state_dict'])

  print('RESUME PRUNE MODEL')

if CUDA:
    model.cuda()
# Out:
# RESUME PRUNE MODEL

# %% [markdown]
# ##設定Optimizer，這裡使用Stocastic Gradient Descent with

# %%
optimizer = optim.SGD(model.parameters(), lr=LEARNING_RATE, momentum=MOMENTUM, weight_decay=WEIGHT_DECAY)

# %% [markdown]
# ## 定義訓練跟測試函數

# %%
#### 訓練函數 #####

train_acc = []
test_acc = []

# 注意: 需自行撰寫儲存每個epoch之train acc的code，以便後續繪製train acc結果圖!
def train(epoch):
    model.train()
    accuracy_per_batch = []
    for batch_idx, (data, target) in enumerate(train_loader):
        if CUDA:
            data, target = data.cuda(), target.cuda()
        data, target = Variable(data), Variable(target)
        optimizer.zero_grad()
        output = model(data)
        loss = F.cross_entropy(output, target)
        loss.backward()
        optimizer.step()
        if batch_idx % LOG_INTERVAL == 0:
            print('\nTrain Epoch: {} [{}/{} ({:.1f}%)]\tLoss: {:.6f}'.format(
                epoch, batch_idx * len(data), len(train_loader.dataset),
                100. * batch_idx / len(train_loader), loss.data.item()))

        # Store training accuracy of current batch
        pred = output.data.max(1, keepdim=True)[1]
        correct = pred.eq(target.data.view_as(pred)).cpu().sum()
        accuracy = correct / float(len(data))
        accuracy_per_batch.append(accuracy)

    # Store training accuracy of current epoch
    train_acc.append(sum(accuracy_per_batch) / len(accuracy_per_batch))


#### 測試函數 ####
def test():
    model.eval()
    test_loss = 0
    correct = 0

    with torch.no_grad():
      for data, target in test_loader:
          if CUDA:
              data, target = data.cuda(), target.cuda()
          data, target = Variable(data), Variable(target)
          output = model(data)
          test_loss += F.cross_entropy(output, target, reduction='sum').data.item()
          pred = output.data.max(1, keepdim=True)[1]
          correct += pred.eq(target.data.view_as(pred)).cpu().sum()

      test_loss /= len(test_loader.dataset)
      print('\nTest set: Average loss: {:.4f}, Accuracy: {}/{} ({:.1f}%)\n'.format(
          test_loss, correct, len(test_loader.dataset),
          100. * correct / len(test_loader.dataset)))
      
      # Store testing accuracy of current epoch
      test_acc.append(correct / float(len(test_loader.dataset)))
      
      return correct / float(len(test_loader.dataset))

best_prec1 = 0.
for epoch in range(START_EPOCH, EPOCHS):
    # Learning Rate在0.5EPOCHS與0.75EPOCHS調整為原本之十分之一
    if epoch in [EPOCHS*0.5, EPOCHS*0.75]:
        for param_group in optimizer.param_groups:
            param_group['lr'] *= 0.1
    train(epoch)
    prec1 = test()

    # 儲存模型權重，方便做後續剪枝,後續訓練
    if(prec1 > best_prec1):
        torch.save({
            'epoch': epoch + 1,
            'state_dict': model.state_dict(),
            'best_prec1': best_prec1,
            'optimizer': optimizer.state_dict(),
        }, PRUNE_FINETUNE_PATH)

    best_prec1 = max(prec1, best_prec1)

print('\n TRAIN PRUNED MODEL DONE!')
# Out:
# Train Epoch: 0 [0/50000 (0.0%)]	Loss: 2.387160
#
# Train Epoch: 0 [10000/50000 (20.0%)]	Loss: 1.676618
#
# Train Epoch: 0 [20000/50000 (40.0%)]	Loss: 1.506252
#
# Train Epoch: 0 [30000/50000 (60.0%)]	Loss: 1.560240
#
# Train Epoch: 0 [40000/50000 (80.0%)]	Loss: 1.334848
#
# Test set: Average loss: 1.3095, Accuracy: 5057/10000 (50.6%)
#
#
# Train Epoch: 1 [0/50000 (0.0%)]	Loss: 1.280899
#
# Train Epoch: 1 [10000/50000 (20.0%)]	Loss: 1.177113
#
# Train Epoch: 1 [20000/50000 (40.0%)]	Loss: 1.230817
#
# Train Epoch: 1 [30000/50000 (60.0%)]	Loss: 1.196989
#
# Train Epoch: 1 [40000/50000 (80.0%)]	Loss: 1.343955
#
# Test set: Average loss: 2.3098, Accuracy: 2197/10000 (22.0%)
#
#
# Train Epoch: 2 [0/50000 (0.0%)]	Loss: 1.264704
#
# Train Epoch: 2 [10000/50000 (20.0%)]	Loss: 1.193020
#
# Train Epoch: 2 [20000/50000 (40.0%)]	Loss: 1.084874
#
# Train Epoch: 2 [30000/50000 (60.0%)]	Loss: 1.163822
#
# Train Epoch: 2 [40000/50000 (80.0%)]	Loss: 1.361711
#
# Test set: Average loss: 2.4586, Accuracy: 1953/10000 (19.5%)
#
#
# Train Epoch: 3 [0/50000 (0.0%)]	Loss: 1.362074
#
# Train Epoch: 3 [10000/50000 (20.0%)]	Loss: 1.101396
#
# Train Epoch: 3 [20000/50000 (40.0%)]	Loss: 1.574557
#
# Train Epoch: 3 [30000/50000 (60.0%)]	Loss: 1.478271
#
# Train Epoch: 3 [40000/50000 (80.0%)]	Loss: 1.058166
#
# Test set: Average loss: 1.2565, Accuracy: 5414/10000 (54.1%)
#
#
# Train Epoch: 4 [0/50000 (0.0%)]	Loss: 1.336401
#
# Train Epoch: 4 [10000/50000 (20.0%)]	Loss: 1.186964
#
# Train Epoch: 4 [20000/50000 (40.0%)]	Loss: 1.530158
#
# Train Epoch: 4 [30000/50000 (60.0%)]	Loss: 1.210348
#
# Train Epoch: 4 [40000/50000 (80.0%)]	Loss: 0.852172
#
# Test set: Average loss: 1.1817, Accuracy: 5866/10000 (58.7%)
#
#
# Train Epoch: 5 [0/50000 (0.0%)]	Loss: 1.076358
#
# Train Epoch: 5 [10000/50000 (20.0%)]	Loss: 1.283600
#
# Train Epoch: 5 [20000/50000 (40.0%)]	Loss: 1.308904
#
# Train Epoch: 5 [30000/50000 (60.0%)]	Loss: 1.301012
#
# Train Epoch: 5 [40000/50000 (80.0%)]	Loss: 1.319323
#
# Test set: Average loss: 1.1609, Accuracy: 5955/10000 (59.5%)
#
#
# Train Epoch: 6 [0/50000 (0.0%)]	Loss: 1.046252
#
# Train Epoch: 6 [10000/50000 (20.0%)]	Loss: 0.878824
#
# Train Epoch: 6 [20000/50000 (40.0%)]	Loss: 0.982147
#
# Train Epoch: 6 [30000/50000 (60.0%)]	Loss: 1.089970
#
# Train Epoch: 6 [40000/50000 (80.0%)]	Loss: 1.294961
#
# Test set: Average loss: 1.1286, Accuracy: 6348/10000 (63.5%)
#
#
# Train Epoch: 7 [0/50000 (0.0%)]	Loss: 1.065140
#
# Train Epoch: 7 [10000/50000 (20.0%)]	Loss: 1.571307
#
# Train Epoch: 7 [20000/50000 (40.0%)]	Loss: 0.932184
#
# Train Epoch: 7 [30000/50000 (60.0%)]	Loss: 1.021813
#
# Train Epoch: 7 [40000/50000 (80.0%)]	Loss: 1.227954
#
# Test set: Average loss: 1.1491, Accuracy: 5998/10000 (60.0%)
#
#
# Train Epoch: 8 [0/50000 (0.0%)]	Loss: 1.584331
#
# Train Epoch: 8 [10000/50000 (20.0%)]	Loss: 1.177450
#
# Train Epoch: 8 [20000/50000 (40.0%)]	Loss: 1.246901
#
# Train Epoch: 8 [30000/50000 (60.0%)]	Loss: 1.209644
#
# Train Epoch: 8 [40000/50000 (80.0%)]	Loss: 1.215741
#
# Test set: Average loss: 1.3035, Accuracy: 5635/10000 (56.3%)
#
#
# Train Epoch: 9 [0/50000 (0.0%)]	Loss: 1.151384
#
# Train Epoch: 9 [10000/50000 (20.0%)]	Loss: 1.242747
#
# Train Epoch: 9 [20000/50000 (40.0%)]	Loss: 1.026929
#
# Train Epoch: 9 [30000/50000 (60.0%)]	Loss: 1.195351
#
# Train Epoch: 9 [40000/50000 (80.0%)]	Loss: 1.144250
#
# Test set: Average loss: 1.0665, Accuracy: 6440/10000 (64.4%)
#
#
# Train Epoch: 10 [0/50000 (0.0%)]	Loss: 1.161743
#
# Train Epoch: 10 [10000/50000 (20.0%)]	Loss: 0.846226
#
# Train Epoch: 10 [20000/50000 (40.0%)]	Loss: 0.950027
#
# Train Epoch: 10 [30000/50000 (60.0%)]	Loss: 0.932592
#
# Train Epoch: 10 [40000/50000 (80.0%)]	Loss: 1.114600
#
# Test set: Average loss: 0.8436, Accuracy: 7035/10000 (70.3%)
#
#
# Train Epoch: 11 [0/50000 (0.0%)]	Loss: 0.908628
#
# Train Epoch: 11 [10000/50000 (20.0%)]	Loss: 0.744856
#
# Train Epoch: 11 [20000/50000 (40.0%)]	Loss: 0.755603
#
# Train Epoch: 11 [30000/50000 (60.0%)]	Loss: 0.846089
#
# Train Epoch: 11 [40000/50000 (80.0%)]	Loss: 0.785416
#
# Test set: Average loss: 0.8257, Accuracy: 7280/10000 (72.8%)
#
#
# Train Epoch: 12 [0/50000 (0.0%)]	Loss: 0.818075
#
# Train Epoch: 12 [10000/50000 (20.0%)]	Loss: 0.712546
#
# Train Epoch: 12 [20000/50000 (40.0%)]	Loss: 0.595320
#
# Train Epoch: 12 [30000/50000 (60.0%)]	Loss: 0.707481
#
# Train Epoch: 12 [40000/50000 (80.0%)]	Loss: 0.602415
#
# Test set: Average loss: 0.7871, Accuracy: 7293/10000 (72.9%)
#
#
# Train Epoch: 13 [0/50000 (0.0%)]	Loss: 0.951083
#
# Train Epoch: 13 [10000/50000 (20.0%)]	Loss: 0.712391
#
# Train Epoch: 13 [20000/50000 (40.0%)]	Loss: 0.602255
#
# Train Epoch: 13 [30000/50000 (60.0%)]	Loss: 0.819428
#
# Train Epoch: 13 [40000/50000 (80.0%)]	Loss: 0.663986
#
# Test set: Average loss: 0.8001, Accuracy: 7282/10000 (72.8%)
#
#
# Train Epoch: 14 [0/50000 (0.0%)]	Loss: 0.754543
#
# Train Epoch: 14 [10000/50000 (20.0%)]	Loss: 0.855553
#
# Train Epoch: 14 [20000/50000 (40.0%)]	Loss: 0.761123
#
# Train Epoch: 14 [30000/50000 (60.0%)]	Loss: 0.724047
#
# Train Epoch: 14 [40000/50000 (80.0%)]	Loss: 0.710858
#
# Test set: Average loss: 0.7415, Accuracy: 7319/10000 (73.2%)
#
#
# Train Epoch: 15 [0/50000 (0.0%)]	Loss: 0.704941
#
# Train Epoch: 15 [10000/50000 (20.0%)]	Loss: 0.713424
#
# Train Epoch: 15 [20000/50000 (40.0%)]	Loss: 0.767463
#
# Train Epoch: 15 [30000/50000 (60.0%)]	Loss: 0.782626
#
# Train Epoch: 15 [40000/50000 (80.0%)]	Loss: 0.698993
#
# Test set: Average loss: 0.7221, Accuracy: 7425/10000 (74.2%)
#
#
# Train Epoch: 16 [0/50000 (0.0%)]	Loss: 1.215387
#
# Train Epoch: 16 [10000/50000 (20.0%)]	Loss: 0.568791
#
# Train Epoch: 16 [20000/50000 (40.0%)]	Loss: 0.720359
#
# Train Epoch: 16 [30000/50000 (60.0%)]	Loss: 0.457379
#
# Train Epoch: 16 [40000/50000 (80.0%)]	Loss: 0.602527
#
# Test set: Average loss: 0.7141, Accuracy: 7522/10000 (75.2%)
#
#
# Train Epoch: 17 [0/50000 (0.0%)]	Loss: 0.625073
#
# Train Epoch: 17 [10000/50000 (20.0%)]	Loss: 0.747537
#
# Train Epoch: 17 [20000/50000 (40.0%)]	Loss: 0.689783
#
# Train Epoch: 17 [30000/50000 (60.0%)]	Loss: 0.660048
#
# Train Epoch: 17 [40000/50000 (80.0%)]	Loss: 0.749022
#
# Test set: Average loss: 0.7311, Accuracy: 7331/10000 (73.3%)
#
#
# Train Epoch: 18 [0/50000 (0.0%)]	Loss: 0.602107
#
# Train Epoch: 18 [10000/50000 (20.0%)]	Loss: 0.619965
#
# Train Epoch: 18 [20000/50000 (40.0%)]	Loss: 0.698591
#
# Train Epoch: 18 [30000/50000 (60.0%)]	Loss: 0.687553
#
# Train Epoch: 18 [40000/50000 (80.0%)]	Loss: 0.477204
#
# Test set: Average loss: 0.7158, Accuracy: 7571/10000 (75.7%)
#
#
# Train Epoch: 19 [0/50000 (0.0%)]	Loss: 0.587875
#
# Train Epoch: 19 [10000/50000 (20.0%)]	Loss: 0.919238
#
# Train Epoch: 19 [20000/50000 (40.0%)]	Loss: 0.590183
#
# Train Epoch: 19 [30000/50000 (60.0%)]	Loss: 0.919195
#
# Train Epoch: 19 [40000/50000 (80.0%)]	Loss: 0.741443
#
# Test set: Average loss: 0.7131, Accuracy: 7545/10000 (75.4%)
#
#
#  TRAIN PRUNED MODEL DONE!

# %% [markdown]
# ## 繪製Fine-tuning結果圖

# %%
#繪製Fine-tuning結果圖
import matplotlib.pyplot as plt
import numpy as np

plt.figure(figsize=(12, 8))
plt.plot(np.arange(1, EPOCHS+1), train_acc, label='Train')
plt.plot(np.arange(1, EPOCHS+1), test_acc, label='Test')
plt.title('Fine-tuning Result')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()
plt.savefig('prune_finetune_result.png')
plt.show()
