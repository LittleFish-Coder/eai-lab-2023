# %% [markdown]
# ##掛載雲端硬碟

# %%
# from google.colab import drive
# drive.mount('/content/drive')

# %% [markdown]
# ##更改檔案所在路徑

# %%
# Change to your own folder !!!
# %cd /content/drive/MyDrive/Colab\ Notebooks/EAI_Lab4_2023

# %% [markdown]
# ## Import library

# %%
from __future__ import print_function
import os
import argparse

import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torchvision import datasets, transforms
from torch.autograd import Variable

from models import vgg

# %% [markdown]
# ## 設定超參數

# %%
TRAIN_BATCH_SIZE = 100
TEST_BATCH_SIZE = 1000
EPOCHS = 20
LEARNING_RATE = 0.1
MOMENTUM = 0.9
WEIGHT_DECAY = 1e-4
LOG_INTERVAL = 100
CUDA = True
SEED = 1

RESUME = True
START_EPOCH = 0

PRUNE_PATH = './model_prune.pth'
PRUNE_FINETUNE_PATH = './model_prune_finetune.pth'

# %% [markdown]
# ####檢查是否檢查是否可使用GPU

# %%
if(torch.cuda.is_available()):
    CUDA = True
    kwargs = {'num_workers': 1, 'pin_memory': True}
    torch.cuda.manual_seed(SEED)
else:
    CUDA = False
    kwargs = {}

# %% [markdown]
# ##下載資料集

# %% [markdown]
# 這裡將訓練集做Augmentation(Pad, RandCrop, Random)，測試集不用做Augmentation

# %%
#### DATASET ####
train_loader = torch.utils.data.DataLoader(
    datasets.CIFAR10('./data', train=True, download=True,
                   transform=transforms.Compose([
                       transforms.Pad(4),
                       transforms.RandomCrop(32),
                       transforms.RandomHorizontalFlip(),
                       transforms.ToTensor(),
                       transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))
                   ])),
    batch_size=TRAIN_BATCH_SIZE, shuffle=True, **kwargs)
test_loader = torch.utils.data.DataLoader(
    datasets.CIFAR10('./data', train=False, transform=transforms.Compose([
                       transforms.ToTensor(),
                       transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))
                   ])),
    batch_size=TEST_BATCH_SIZE, shuffle=True, **kwargs)
# Out:
# Files already downloaded and verified

# %% [markdown]
# ## 載入剪枝後的網路與權重

# %%
model = None
if(RESUME):
  checkpoint = torch.load(PRUNE_PATH)
  model = vgg(cfg=checkpoint['cfg'])
  model.load_state_dict(checkpoint['state_dict'])

  print('RESUME PRUNE MODEL')

if CUDA:
    model.cuda()
# Out:
# RESUME PRUNE MODEL

# %% [markdown]
# ##設定Optimizer，這裡使用Stocastic Gradient Descent with

# %%
optimizer = optim.SGD(model.parameters(), lr=LEARNING_RATE, momentum=MOMENTUM, weight_decay=WEIGHT_DECAY)

# %% [markdown]
# ## 定義訓練跟測試函數

# %%
#### 訓練函數 #####

train_acc = []
test_acc = []

# 注意: 需自行撰寫儲存每個epoch之train acc的code，以便後續繪製train acc結果圖!
def train(epoch):
    model.train()
    accuracy_per_batch = []
    for batch_idx, (data, target) in enumerate(train_loader):
        if CUDA:
            data, target = data.cuda(), target.cuda()
        data, target = Variable(data), Variable(target)
        optimizer.zero_grad()
        output = model(data)
        loss = F.cross_entropy(output, target)
        loss.backward()
        optimizer.step()
        if batch_idx % LOG_INTERVAL == 0:
            print('\nTrain Epoch: {} [{}/{} ({:.1f}%)]\tLoss: {:.6f}'.format(
                epoch, batch_idx * len(data), len(train_loader.dataset),
                100. * batch_idx / len(train_loader), loss.data.item()))

        # Store training accuracy of current batch
        pred = output.data.max(1, keepdim=True)[1]
        correct = pred.eq(target.data.view_as(pred)).cpu().sum()
        accuracy = correct / float(len(data))
        accuracy_per_batch.append(accuracy)

    # Store training accuracy of current epoch
    train_acc.append(sum(accuracy_per_batch) / len(accuracy_per_batch))


#### 測試函數 ####
def test():
    model.eval()
    test_loss = 0
    correct = 0

    with torch.no_grad():
      for data, target in test_loader:
          if CUDA:
              data, target = data.cuda(), target.cuda()
          data, target = Variable(data), Variable(target)
          output = model(data)
          test_loss += F.cross_entropy(output, target, reduction='sum').data.item()
          pred = output.data.max(1, keepdim=True)[1]
          correct += pred.eq(target.data.view_as(pred)).cpu().sum()

      test_loss /= len(test_loader.dataset)
      print('\nTest set: Average loss: {:.4f}, Accuracy: {}/{} ({:.1f}%)\n'.format(
          test_loss, correct, len(test_loader.dataset),
          100. * correct / len(test_loader.dataset)))
      
      # Store testing accuracy of current epoch
      test_acc.append(correct / float(len(test_loader.dataset)))
      
      return correct / float(len(test_loader.dataset))

best_prec1 = 0.
for epoch in range(START_EPOCH, EPOCHS):
    # Learning Rate在0.5EPOCHS與0.75EPOCHS調整為原本之十分之一
    if epoch in [EPOCHS*0.5, EPOCHS*0.75]:
        for param_group in optimizer.param_groups:
            param_group['lr'] *= 0.1
    train(epoch)
    prec1 = test()

    # 儲存模型權重，方便做後續剪枝,後續訓練
    if(prec1 > best_prec1):
        torch.save({
            'epoch': epoch + 1,
            'state_dict': model.state_dict(),
            'best_prec1': best_prec1,
            'optimizer': optimizer.state_dict(),
        }, PRUNE_FINETUNE_PATH)

    best_prec1 = max(prec1, best_prec1)

print('\n TRAIN PRUNED MODEL DONE!')
# Out:
# Train Epoch: 0 [0/50000 (0.0%)]	Loss: 2.334672
#
# Train Epoch: 0 [10000/50000 (20.0%)]	Loss: 1.417471
#
# Train Epoch: 0 [20000/50000 (40.0%)]	Loss: 1.459429
#
# Train Epoch: 0 [30000/50000 (60.0%)]	Loss: 1.170985
#
# Train Epoch: 0 [40000/50000 (80.0%)]	Loss: 1.181843
#
# Test set: Average loss: 1.2630, Accuracy: 4517/10000 (45.2%)
#
#
# Train Epoch: 1 [0/50000 (0.0%)]	Loss: 1.350935
#
# Train Epoch: 1 [10000/50000 (20.0%)]	Loss: 1.399091
#
# Train Epoch: 1 [20000/50000 (40.0%)]	Loss: 1.284814
#
# Train Epoch: 1 [30000/50000 (60.0%)]	Loss: 1.453475
#
# Train Epoch: 1 [40000/50000 (80.0%)]	Loss: 1.056461
#
# Test set: Average loss: 1.5021, Accuracy: 4657/10000 (46.6%)
#
#
# Train Epoch: 2 [0/50000 (0.0%)]	Loss: 1.228150
#
# Train Epoch: 2 [10000/50000 (20.0%)]	Loss: 1.139096
#
# Train Epoch: 2 [20000/50000 (40.0%)]	Loss: 1.356456
#
# Train Epoch: 2 [30000/50000 (60.0%)]	Loss: 1.086520
#
# Train Epoch: 2 [40000/50000 (80.0%)]	Loss: 1.188928
#
# Test set: Average loss: 1.5588, Accuracy: 3633/10000 (36.3%)
#
#
# Train Epoch: 3 [0/50000 (0.0%)]	Loss: 1.162687
#
# Train Epoch: 3 [10000/50000 (20.0%)]	Loss: 1.101168
#
# Train Epoch: 3 [20000/50000 (40.0%)]	Loss: 1.114026
#
# Train Epoch: 3 [30000/50000 (60.0%)]	Loss: 1.535118
#
# Train Epoch: 3 [40000/50000 (80.0%)]	Loss: 1.415354
#
# Test set: Average loss: 1.0856, Accuracy: 6195/10000 (62.0%)
#
#
# Train Epoch: 4 [0/50000 (0.0%)]	Loss: 0.927124
#
# Train Epoch: 4 [10000/50000 (20.0%)]	Loss: 0.895934
#
# Train Epoch: 4 [20000/50000 (40.0%)]	Loss: 1.107981
#
# Train Epoch: 4 [30000/50000 (60.0%)]	Loss: 1.121480
#
# Train Epoch: 4 [40000/50000 (80.0%)]	Loss: 1.041753
#
# Test set: Average loss: 1.2908, Accuracy: 5379/10000 (53.8%)
#
#
# Train Epoch: 5 [0/50000 (0.0%)]	Loss: 0.965028
#
# Train Epoch: 5 [10000/50000 (20.0%)]	Loss: 1.255398
#
# Train Epoch: 5 [20000/50000 (40.0%)]	Loss: 1.086152
#
# Train Epoch: 5 [30000/50000 (60.0%)]	Loss: 1.204338
#
# Train Epoch: 5 [40000/50000 (80.0%)]	Loss: 1.232483
#
# Test set: Average loss: 1.2176, Accuracy: 5425/10000 (54.2%)
#
#
# Train Epoch: 6 [0/50000 (0.0%)]	Loss: 1.222137
#
# Train Epoch: 6 [10000/50000 (20.0%)]	Loss: 1.030276
#
# Train Epoch: 6 [20000/50000 (40.0%)]	Loss: 1.089214
#
# Train Epoch: 6 [30000/50000 (60.0%)]	Loss: 1.100067
#
# Train Epoch: 6 [40000/50000 (80.0%)]	Loss: 1.622494
#
# Test set: Average loss: 1.0513, Accuracy: 6258/10000 (62.6%)
#
#
# Train Epoch: 7 [0/50000 (0.0%)]	Loss: 1.045895
#
# Train Epoch: 7 [10000/50000 (20.0%)]	Loss: 1.085188
#
# Train Epoch: 7 [20000/50000 (40.0%)]	Loss: 0.910597
#
# Train Epoch: 7 [30000/50000 (60.0%)]	Loss: 1.151529
#
# Train Epoch: 7 [40000/50000 (80.0%)]	Loss: 1.293168
#
# Test set: Average loss: 1.2698, Accuracy: 5224/10000 (52.2%)
#
#
# Train Epoch: 8 [0/50000 (0.0%)]	Loss: 1.130799
#
# Train Epoch: 8 [10000/50000 (20.0%)]	Loss: 0.971666
#
# Train Epoch: 8 [20000/50000 (40.0%)]	Loss: 1.174948
#
# Train Epoch: 8 [30000/50000 (60.0%)]	Loss: 1.105600
#
# Train Epoch: 8 [40000/50000 (80.0%)]	Loss: 1.054085
#
# Test set: Average loss: 1.1847, Accuracy: 5603/10000 (56.0%)
#
#
# Train Epoch: 9 [0/50000 (0.0%)]	Loss: 1.032159
#
# Train Epoch: 9 [10000/50000 (20.0%)]	Loss: 0.971092
#
# Train Epoch: 9 [20000/50000 (40.0%)]	Loss: 0.963614
#
# Train Epoch: 9 [30000/50000 (60.0%)]	Loss: 1.263677
#
# Train Epoch: 9 [40000/50000 (80.0%)]	Loss: 1.106213
#
# Test set: Average loss: 1.0157, Accuracy: 6489/10000 (64.9%)
#
#
# Train Epoch: 10 [0/50000 (0.0%)]	Loss: 0.952236
#
# Train Epoch: 10 [10000/50000 (20.0%)]	Loss: 0.795880
#
# Train Epoch: 10 [20000/50000 (40.0%)]	Loss: 0.923710
#
# Train Epoch: 10 [30000/50000 (60.0%)]	Loss: 0.928293
#
# Train Epoch: 10 [40000/50000 (80.0%)]	Loss: 0.570046
#
# Test set: Average loss: 0.8036, Accuracy: 7091/10000 (70.9%)
#
#
# Train Epoch: 11 [0/50000 (0.0%)]	Loss: 0.864299
#
# Train Epoch: 11 [10000/50000 (20.0%)]	Loss: 0.832491
#
# Train Epoch: 11 [20000/50000 (40.0%)]	Loss: 0.972385
#
# Train Epoch: 11 [30000/50000 (60.0%)]	Loss: 0.768157
#
# Train Epoch: 11 [40000/50000 (80.0%)]	Loss: 0.685180
#
# Test set: Average loss: 0.7631, Accuracy: 7125/10000 (71.2%)
#
#
# Train Epoch: 12 [0/50000 (0.0%)]	Loss: 0.894965
#
# Train Epoch: 12 [10000/50000 (20.0%)]	Loss: 0.608996
#
# Train Epoch: 12 [20000/50000 (40.0%)]	Loss: 0.743626
#
# Train Epoch: 12 [30000/50000 (60.0%)]	Loss: 0.678276
#
# Train Epoch: 12 [40000/50000 (80.0%)]	Loss: 0.686960
#
# Test set: Average loss: 0.7618, Accuracy: 7322/10000 (73.2%)
#
#
# Train Epoch: 13 [0/50000 (0.0%)]	Loss: 0.752815
#
# Train Epoch: 13 [10000/50000 (20.0%)]	Loss: 0.723447
#
# Train Epoch: 13 [20000/50000 (40.0%)]	Loss: 0.669398
#
# Train Epoch: 13 [30000/50000 (60.0%)]	Loss: 0.792171
#
# Train Epoch: 13 [40000/50000 (80.0%)]	Loss: 0.760665
#
# Test set: Average loss: 0.7637, Accuracy: 7173/10000 (71.7%)
#
#
# Train Epoch: 14 [0/50000 (0.0%)]	Loss: 0.834460
#
# Train Epoch: 14 [10000/50000 (20.0%)]	Loss: 0.723720
#
# Train Epoch: 14 [20000/50000 (40.0%)]	Loss: 0.670957
#
# Train Epoch: 14 [30000/50000 (60.0%)]	Loss: 0.908838
#
# Train Epoch: 14 [40000/50000 (80.0%)]	Loss: 0.766457
#
# Test set: Average loss: 0.7746, Accuracy: 7144/10000 (71.4%)
#
#
# Train Epoch: 15 [0/50000 (0.0%)]	Loss: 0.685307
#
# Train Epoch: 15 [10000/50000 (20.0%)]	Loss: 0.685515
#
# Train Epoch: 15 [20000/50000 (40.0%)]	Loss: 0.568732
#
# Train Epoch: 15 [30000/50000 (60.0%)]	Loss: 0.758380
#
# Train Epoch: 15 [40000/50000 (80.0%)]	Loss: 0.573829
#
# Test set: Average loss: 0.7280, Accuracy: 7440/10000 (74.4%)
#
#
# Train Epoch: 16 [0/50000 (0.0%)]	Loss: 0.729968
#
# Train Epoch: 16 [10000/50000 (20.0%)]	Loss: 0.797559
#
# Train Epoch: 16 [20000/50000 (40.0%)]	Loss: 0.706100
#
# Train Epoch: 16 [30000/50000 (60.0%)]	Loss: 0.813520
#
# Train Epoch: 16 [40000/50000 (80.0%)]	Loss: 0.578110
#
# Test set: Average loss: 0.7175, Accuracy: 7377/10000 (73.8%)
#
#
# Train Epoch: 17 [0/50000 (0.0%)]	Loss: 0.713205
#
# Train Epoch: 17 [10000/50000 (20.0%)]	Loss: 0.586076
#
# Train Epoch: 17 [20000/50000 (40.0%)]	Loss: 0.610626
#
# Train Epoch: 17 [30000/50000 (60.0%)]	Loss: 0.583017
#
# Train Epoch: 17 [40000/50000 (80.0%)]	Loss: 0.726704
#
# Test set: Average loss: 0.7158, Accuracy: 7432/10000 (74.3%)
#
#
# Train Epoch: 18 [0/50000 (0.0%)]	Loss: 0.723248
#
# Train Epoch: 18 [10000/50000 (20.0%)]	Loss: 0.627658
#
# Train Epoch: 18 [20000/50000 (40.0%)]	Loss: 0.667911
#
# Train Epoch: 18 [30000/50000 (60.0%)]	Loss: 0.545917
#
# Train Epoch: 18 [40000/50000 (80.0%)]	Loss: 0.790409
#
# Test set: Average loss: 0.7095, Accuracy: 7364/10000 (73.6%)
#
#
# Train Epoch: 19 [0/50000 (0.0%)]	Loss: 0.778281
#
# Train Epoch: 19 [10000/50000 (20.0%)]	Loss: 0.583644
#
# Train Epoch: 19 [20000/50000 (40.0%)]	Loss: 0.840223
#
# Train Epoch: 19 [30000/50000 (60.0%)]	Loss: 0.602849
#
# Train Epoch: 19 [40000/50000 (80.0%)]	Loss: 0.712723
#
# Test set: Average loss: 0.7120, Accuracy: 7379/10000 (73.8%)
#
#
#  TRAIN PRUNED MODEL DONE!

# %% [markdown]
# ## 繪製Fine-tuning結果圖

# %%
#繪製Fine-tuning結果圖
import matplotlib.pyplot as plt
import numpy as np

plt.figure(figsize=(12, 8))
plt.plot(np.arange(1, EPOCHS+1), train_acc, label='Train')
plt.plot(np.arange(1, EPOCHS+1), test_acc, label='Test')
plt.title('Fine-tuning Result - Prune Ratio: 0.9')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()
plt.savefig('prune_finetune_result_09.png')
plt.show()
